# %%
'''
Copying all Repos that are functional and contain vulnerabilities
'''

import shutil
import os

# Define the paths for your folders
source_folder = "All HELM REPOS"
destination_folder = "Usable REPOS"
list_file = "repos_list.txt"  # The text file containing the names of the repos you want to copy

# Ensure destination folder exists
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Read the list of repos from the text file
with open(list_file, 'r') as file:
    repos_to_copy = file.read().splitlines()

# Iterate over the list and copy the repositories
for repo_name in repos_to_copy:
    source_repo = os.path.join(source_folder, repo_name)
    destination_repo = os.path.join(destination_folder, repo_name)

    # Check if the repo exists before attempting to copy
    if os.path.exists(source_repo):
        try:
            shutil.copy(source_repo, destination_repo)
            print(f"Copied: {repo_name}")
        except Exception as e:
            print(f"Failed to copy {repo_name}: {e}")
    else:
        print(f"Repo not found: {repo_name}")

print("Copy operation complete.")

# %%
'''
Copying all Repos that contain a 'Security Context' in their values.yaml file
'''


import os
import tarfile
import yaml

# Recursive function to search for 'securityContext' in nested structures
def find_security_context(data):
    if isinstance(data, dict):
        if "securityContext" in data:
            return True
        for key, value in data.items():
            if find_security_context(value):
                return True
    elif isinstance(data, list):
        for item in data:
            if find_security_context(item):
                return True
    return False

# Paths
helm_repo_folder = "Usable REPOS"
success_file = "success.txt"
failure_file = "failure.txt"

# Initialize counts
success_count = 0
failure_count = 0

# Open result files
with open(success_file, 'w') as success_log, open(failure_file, 'w') as failure_log:
    # Iterate through each .tgz file in the folder
    for tgz_file in os.listdir(helm_repo_folder):
        if tgz_file.endswith(".tgz"):
            tgz_path = os.path.join(helm_repo_folder, tgz_file)

            try:
                # Open the tar.gz file
                with tarfile.open(tgz_path, 'r:gz') as tar:
                    found_values_yaml = False  # Variable to track if we've found the values.yaml

                    # Extract members to find values.yaml
                    for member in tar.getmembers():
                        if "values.yaml" in member.name and not found_values_yaml:
                            # Extract and read the values.yaml file
                            values_file = tar.extractfile(member)
                            if values_file:
                                values_yaml = yaml.safe_load(values_file)

                                # Ensure values_yaml is not None before checking for "securityContext"
                                if values_yaml and isinstance(values_yaml, dict):
                                    if find_security_context(values_yaml):
                                        success_count += 1
                                        success_log.write(f"{tgz_file}\n")
                                    else:
                                        failure_count += 1
                                        failure_log.write(f"{tgz_file}\n")
                                else:
                                    # Handle the case where the file could not be parsed or is empty
                                    failure_count += 1
                                    failure_log.write(f"{tgz_file} (Invalid or empty values.yaml)\n")
                                
                                found_values_yaml = True  # Mark that we've processed this repo
                                break  # Stop after processing the first values.yaml file
                    else:
                        # If no values.yaml file was found in the tar archive, mark it as a failure
                        failure_count += 1
                        failure_log.write(f"{tgz_file} (No values.yaml found)\n")
                        
            except Exception as e:
                # Log any errors encountered during processing
                failure_count += 1
                failure_log.write(f"{tgz_file} (Error: {str(e)})\n")

# Print final counts
print(f"Success count: {success_count}")
print(f"Failure count: {failure_count}")
# Out:
# Success count: 2452
# Failure count: 3075

# %%
import os
import shutil

# Paths
usable_repos_folder = "Usable REPOS"  # Update this with the correct folder path
success_file = "success.txt"
new_folder = "SecurityContextRepos"  # Update this with the destination folder path

# Create the new folder if it doesn't exist
if not os.path.exists(new_folder):
    os.makedirs(new_folder)

# Read the success.txt file
with open(success_file, 'r') as file:
    successful_repos = file.read().splitlines()

# Copy each repository from the Usable REPOS folder to the new folder
for repo in successful_repos:
    repo_path = os.path.join(usable_repos_folder, repo)
    if os.path.exists(repo_path):
        shutil.copy(repo_path, new_folder)
        print(f"Copied {repo} to {new_folder}")
    else:
        print(f"Repository {repo} not found in {usable_repos_folder}")

print("Copy operation completed.")
# Out:
# Copied 12factor-22.5.11.tgz to path_to_your_new_folder
# Copied 389ds-0.1.0.tgz to path_to_your_new_folder
# Copied access-control-srv-0.1.15.tgz to path_to_your_new_folder
# Copied access-manager-0.13.0.tgz to path_to_your_new_folder
# Copied accounts-ui-v2023.10.18.tgz to path_to_your_new_folder
# Copied ace-v2023.10.18.tgz to path_to_your_new_folder
# Copied acestream-3.0.0.tgz to path_to_your_new_folder
# Copied actions-runner-controller-0.23.5.tgz to path_to_your_new_folder
# Copied activityrelay-1.0.31.tgz to path_to_your_new_folder
# Copied adguard-0.12.tgz to path_to_your_new_folder
# Copied adminui-0.15.0.tgz to path_to_your_new_folder
# Copied adresservice-1.1.0.tgz to path_to_your_new_folder
# Copied adventureworks-0.1.0.tgz to path_to_your_new_folder
# Copied ae-1.1.44.tgz to path_to_your_new_folder
# Copied aerospike-kubernetes-operator-3.0.0.tgz to path_to_your_new_folder
# Copied aerospike-rest-client-0.1.0.tgz to path_to_your_new_folder
# Copied agents-0.1.29.tgz to path_to_your_new_folder
# Copied airsonic-advanced-0.2.0.tgz to path_to_your_new_folder
# Copied akash-hostname-operator-6.0.4.tgz to path_to_your_new_folder
# Copied akash-node-6.0.6.tgz to path_to_your_new_folder
# Copied akeyless-api-gateway-1.33.7.tgz to path_to_your_new_folder
# Copied akhq-0.24.0.tgz to path_to_your_new_folder
# Copied aleksis-0.4.2.tgz to path_to_your_new_folder
# Copied alertmanager-gchat-integration-1.0.5.tgz to path_to_your_new_folder
# Copied alertmanager-matrix-forwarder-1.0.1.tgz to path_to_your_new_folder
# Copied alertmanager-snmp-notifier-0.1.2.tgz to path_to_your_new_folder
# Copied alertmanager-webhook-adaptor-0.1.4.tgz to path_to_your_new_folder
# Copied alienswarm-2.0.8.tgz to path_to_your_new_folder
# Copied alienswarm-reactivedrop-2.0.9.tgz to path_to_your_new_folder
# Copied aliyun-exporter-0.1.0.tgz to path_to_your_new_folder
# Copied alphafold-gradio-0.1.0.tgz to path_to_your_new_folder
# Copied am-4.1.5.tgz to path_to_your_new_folder
# Copied amass-4.3.0.tgz to path_to_your_new_folder
# Copied amazon-ec2-metadata-mock-1.11.2.tgz to path_to_your_new_folder
# Copied amazon-eks-pod-identity-webhook-2.1.3.tgz to path_to_your_new_folder
# Copied ambassador-agent-1.0.21.tgz to path_to_your_new_folder
# Copied amd-gpu-0.10.0.tgz to path_to_your_new_folder
# Copied americasarmy-pg-2.0.9.tgz to path_to_your_new_folder
# Copied amtd-2.0.9.tgz to path_to_your_new_folder
# Copied amvd-2.0.9.tgz to path_to_your_new_folder
# Copied anchore-engine-1.28.3.tgz to path_to_your_new_folder
# Copied android-8-0-2.0.9.tgz to path_to_your_new_folder
# Copied androiddebugbridge-2.0.9.tgz to path_to_your_new_folder
# Copied angularjs-csti-scanner-3.15.2.tgz to path_to_your_new_folder
# Copied annotations-exporter-0.5.0.tgz to path_to_your_new_folder
# Copied anope-2.0.9.tgz to path_to_your_new_folder
# Copied ansible-semaphore-0.1.0.tgz to path_to_your_new_folder
# Copied anx-cloud-controller-manager-0.1.0.tgz to path_to_your_new_folder
# Copied aoderelay-0.1.10.tgz to path_to_your_new_folder
# Copied apache-ranger-admin-0.2.0.tgz to path_to_your_new_folder
# Copied apache-webdav-2.0.9.tgz to path_to_your_new_folder
# Copied apecloud-oteld-0.2.0.tgz to path_to_your_new_folder
# Copied api-firewall-0.6.13.tgz to path_to_your_new_folder
# Copied api-server-0.11.16.tgz to path_to_your_new_folder
# Copied apicurio-1.0.14.tgz to path_to_your_new_folder
# Copied apicurio-registry-sql-0.1.0.tgz to path_to_your_new_folder
# Copied apid-helper-0.1.4.tgz to path_to_your_new_folder
# Copied apim-4.1.3.tgz to path_to_your_new_folder
# Copied apim3-4.1.3.tgz to path_to_your_new_folder
# Copied apiping-1.3.2.tgz to path_to_your_new_folder
# Copied apisix-0.1.7.tgz to path_to_your_new_folder
# Copied apisix-dashboard-0.8.1.tgz to path_to_your_new_folder
# Copied apisix-ingress-controller-0.12.2.tgz to path_to_your_new_folder
# Copied apm-server-0.1.2.tgz to path_to_your_new_folder
# Copied app-component-1.4.3.tgz to path_to_your_new_folder
# Copied app-config-frontend-1.0.2.tgz to path_to_your_new_folder
# Copied appcatalog-v2023.03.23.tgz to path_to_your_new_folder
# Copied applause-btn-0.1.1.tgz to path_to_your_new_folder
# Copied apprise-api-3.0.1.tgz to path_to_your_new_folder
# Copied approuvez-0.1.1.tgz to path_to_your_new_folder
# Copied appswitcher-server-1.1.0.tgz to path_to_your_new_folder
# Copied aptly-0.4.0.tgz to path_to_your_new_folder
# Copied ara-0.4.1.tgz to path_to_your_new_folder
# Copied archisteamfarm-0.3.0.tgz to path_to_your_new_folder
# Copied archiva-0.0.7.tgz to path_to_your_new_folder
# Copied archiveteam-warrior-2.0.11.tgz to path_to_your_new_folder
# Copied argo-controller-0.0.10.tgz to path_to_your_new_folder
# Copied argo-events-2.4.1.tgz to path_to_your_new_folder
# Copied argo-workflows-0.39.0.tgz to path_to_your_new_folder
# Copied argocd-image-updater-0.9.1.tgz to path_to_your_new_folder
# Copied argus-test-env-2.0.0.tgz to path_to_your_new_folder
# Copied ark-cluster-0.1.14.tgz to path_to_your_new_folder
# Copied arklb-0.1.11.tgz to path_to_your_new_folder
# Copied arma-reforger-0.5.3.tgz to path_to_your_new_folder
# Copied arma3-2.0.8.tgz to path_to_your_new_folder
# Copied arma3exilemod-2.0.9.tgz to path_to_your_new_folder
# Copied armory-spinnaker-operator-1.8.9.tgz to path_to_your_new_folder
# Copied arr-1.0.9.tgz to path_to_your_new_folder
# Copied arroyo-0.7.1.tgz to path_to_your_new_folder
# Copied artifact-hub-1.16.0.tgz to path_to_your_new_folder
# Copied artifactory-107.71.4.tgz to path_to_your_new_folder
# Copied artifactory-ha-107.71.4.tgz to path_to_your_new_folder
# Copied assettocorsa-2.0.9.tgz to path_to_your_new_folder
# Copied assistant-relay-0.1.2.tgz to path_to_your_new_folder
# Copied astral-0.1.0.tgz to path_to_your_new_folder
# Copied atemlire-3.0.2.tgz to path_to_your_new_folder
# Copied atlantis-4.17.0.tgz to path_to_your_new_folder
# Copied atlassian-confluence-3.4.1.tgz to path_to_your_new_folder
# Copied atlassian-jira-3.3.2.tgz to path_to_your_new_folder
# Copied ats-ingress-0.1.0.tgz to path_to_your_new_folder
# Copied atuin-0.5.0.tgz to path_to_your_new_folder
# Copied auditor-v2023.10.1.tgz to path_to_your_new_folder
# Copied aurora-files-2.0.9.tgz to path_to_your_new_folder
# Copied auth-22.4.2.tgz to path_to_your_new_folder
# Copied authentication-0.11.0.tgz to path_to_your_new_folder
# Copied authentication-service-0.2.2.tgz to path_to_your_new_folder
# Copied authentik-2023.10.3.tgz to path_to_your_new_folder
# Copied auto-discovery-cloud-aws-4.3.0.tgz to path_to_your_new_folder
# Copied auto-discovery-kubernetes-4.3.0.tgz to path_to_your_new_folder
# Copied auto-yt-dl-2.0.12.tgz to path_to_your_new_folder
# Copied autodelete-discord-0.6.1.tgz to path_to_your_new_folder
# Copied autonodelabel-0.0.6.tgz to path_to_your_new_folder
# Copied avorion-2.0.9.tgz to path_to_your_new_folder
# Copied awesome-ttrss-3.0.22.tgz to path_to_your_new_folder
# Copied aws-api-gateway-operator-0.1.2.tgz to path_to_your_new_folder
# Copied aws-cloudwatch-logs-streamer-0.1.0.tgz to path_to_your_new_folder
# Copied aws-container-insight-fluent-bit-0.1.0.tgz to path_to_your_new_folder
# Copied aws-ebs-csi-driver-2.17.1.tgz to path_to_your_new_folder
# Copied aws-efs-csi-driver-2.5.1.tgz to path_to_your_new_folder
# Copied aws-eks-asg-rolling-update-handler-1.5.0.tgz to path_to_your_new_folder
# Copied aws-fsx-csi-driver-0.1.0.tgz to path_to_your_new_folder
# Copied aws-node-termination-handler-0.21.0.tgz to path_to_your_new_folder
# Copied aws-node-termination-handler-2-0.2.0.tgz to path_to_your_new_folder
# Copied aws-s3-proxy-0.1.4.tgz to path_to_your_new_folder
# Copied aws-service-events-exporter-1.0.5.tgz to path_to_your_new_folder
# Copied aws-service-quotas-exporter-0.1.2.tgz to path_to_your_new_folder
# Copied aws-vpc-cni-1.15.3.tgz to path_to_your_new_folder
# Copied aws-xray-4.0.5.tgz to path_to_your_new_folder
# Copied axelor-open-suite-7.1.3.tgz to path_to_your_new_folder
# Copied axosyslog-collector-0.5.0.tgz to path_to_your_new_folder
# Copied azure-app-exporter-0.1.0.tgz to path_to_your_new_folder
# Copied azure-janitor-1.0.9.tgz to path_to_your_new_folder
# Copied azure-keyvault-exporter-1.0.8.tgz to path_to_your_new_folder
# Copied azure-loganalytics-exporter-1.0.5.tgz to path_to_your_new_folder
# Copied azure-metrics-exporter-1.2.0.tgz to path_to_your_new_folder
# Copied azure-pipelines-agent-2.2.26.tgz to path_to_your_new_folder
# Copied azure-resourcegraph-exporter-1.1.0.tgz to path_to_your_new_folder
# Copied azure-resourcemanager-exporter-1.3.0.tgz to path_to_your_new_folder
# Copied azure-scheduledevents-manager-1.0.13.tgz to path_to_your_new_folder
# Copied baaza-0.1.5.tgz to path_to_your_new_folder
# Copied back8sup-0.4.8.tgz to path_to_your_new_folder
# Copied backend-2.4.24.tgz to path_to_your_new_folder
# Copied backup-exporter-0.1.0.tgz to path_to_your_new_folder
# Copied backup-maker-controller-v0.1.2.tgz to path_to_your_new_folder
# Copied backup-repository-server-v4.0.0.tgz to path_to_your_new_folder
# Copied backuppc-0.0.2.tgz to path_to_your_new_folder
# Copied backyards-sre-0.1.0.tgz to path_to_your_new_folder
# Copied backyards-sre-alert-exporter-0.1.0.tgz to path_to_your_new_folder
# Copied baget-1.0.5.tgz to path_to_your_new_folder
# Copied bar-0.1.0.tgz to path_to_your_new_folder
# Copied barcodebuddy-2.0.11.tgz to path_to_your_new_folder
# Copied barotrauma-2.0.9.tgz to path_to_your_new_folder
# Copied base-job-0.1.0.tgz to path_to_your_new_folder
# Copied base-resource-pack-1.0.0.tgz to path_to_your_new_folder
# Copied base-web-0.1.0.tgz to path_to_your_new_folder
# Copied baseapp-0.1.0.tgz to path_to_your_new_folder
# Copied baserow-1.27.0.tgz to path_to_your_new_folder
# Copied basic-web-app-1.1.0.tgz to path_to_your_new_folder
# Copied basisregister-fictieve-kentekens-0.1.1.tgz to path_to_your_new_folder
# Copied bazel-remote-0.0.6.tgz to path_to_your_new_folder
# Copied bbrf-server-0.1.0.tgz to path_to_your_new_folder
# Copied beacon-metrics-gazer-0.1.3.tgz to path_to_your_new_folder
# Copied beaconchain-explorer-0.1.4.tgz to path_to_your_new_folder
# Copied bee-0.14.4.tgz to path_to_your_new_folder
# Copied bender-2.0.9.tgz to path_to_your_new_folder
# Copied billing-ui-v2023.10.18.tgz to path_to_your_new_folder
# Copied billing-v2023.10.18.tgz to path_to_your_new_folder
# Copied binaryvision-static-wordpress-0.0.4.tgz to path_to_your_new_folder
# Copied binaryvision-tlo-0.0.4.tgz to path_to_your_new_folder
# Copied bind-0.1.0.tgz to path_to_your_new_folder
# Copied bisc-taalhuizen-0.1.2.tgz to path_to_your_new_folder
# Copied bitcoin-node-2.0.11.tgz to path_to_your_new_folder
# Copied bitcoind-2.0.8.tgz to path_to_your_new_folder
# Copied bitcoinunlimited-2.0.9.tgz to path_to_your_new_folder
# Copied bitcoinwalletgui-2.0.9.tgz to path_to_your_new_folder
# Copied bitpoke-1.8.14.tgz to path_to_your_new_folder
# Copied bitwarden-0.12.tgz to path_to_your_new_folder
# Copied bitwardenrs-0.5.1.tgz to path_to_your_new_folder
# Copied blender-2.0.18.tgz to path_to_your_new_folder
# Copied blender-desktop-g3-2.0.10.tgz to path_to_your_new_folder
# Copied blob-me-baby-0.1.1.tgz to path_to_your_new_folder
# Copied blobscan-0.1.1.tgz to path_to_your_new_folder
# Copied blobscan-indexer-0.1.1.tgz to path_to_your_new_folder
# Copied blockscout-0.2.0.tgz to path_to_your_new_folder
# Copied bnkr-1.0.5.tgz to path_to_your_new_folder
# Copied bodgeit-4.3.0.tgz to path_to_your_new_folder
# Copied bookstack-0.1.1.tgz to path_to_your_new_folder
# Copied bor-0.0.4.tgz to path_to_your_new_folder
# Copied botkube-v1.5.0.tgz to path_to_your_new_folder
# Copied bottlerocket-brupop-0.4.5.tgz to path_to_your_new_folder
# Copied bottlerocket-update-operator-0.3.0.tgz to path_to_your_new_folder
# Copied boundary-0.2.7.tgz to path_to_your_new_folder
# Copied boundary-softsci-0.2.4.tgz to path_to_your_new_folder
# Copied bpa-0.12.4.tgz to path_to_your_new_folder
# Copied bredbandskollen-prometheus-exporter-0.2.3.tgz to path_to_your_new_folder
# Copied breitbandmessung-de-2.0.9.tgz to path_to_your_new_folder
# Copied briefkasten-0.0.15.tgz to path_to_your_new_folder
# Copied browserless-0.1.1.tgz to path_to_your_new_folder
# Copied browserless-chrome-0.0.4.tgz to path_to_your_new_folder
# Copied brpservice-1.1.0.tgz to path_to_your_new_folder
# Copied brudi-operator-0.1.5.tgz to path_to_your_new_folder
# Copied btdex-2.0.9.tgz to path_to_your_new_folder
# Copied budgie-0.1.2.tgz to path_to_your_new_folder
# Copied budibase-2.12.11.tgz to path_to_your_new_folder
# Copied buildachart-0.1.0.tgz to path_to_your_new_folder
# Copied buildbarn-0.0.1.tgz to path_to_your_new_folder
# Copied business-central-2.2.14.tgz to path_to_your_new_folder
# Copied business-service-0.2.1.tgz to path_to_your_new_folder
# Copied butlerci-0.1.0.tgz to path_to_your_new_folder
# Copied bwapp-2.0.9.tgz to path_to_your_new_folder
# Copied bytesafe-ce-1.0.4.tgz to path_to_your_new_folder
# Copied bzz-token-service-0.1.1.tgz to path_to_your_new_folder
# Copied caasperli-0.10.4.tgz to path_to_your_new_folder
# Copied cachet-1.3.2.tgz to path_to_your_new_folder
# Copied caddy-0.0.14.tgz to path_to_your_new_folder
# Copied cadence-0.23.0.tgz to path_to_your_new_folder
# Copied cadquery-jupyter-2.0.9.tgz to path_to_your_new_folder
# Copied cadquery-server-2.0.9.tgz to path_to_your_new_folder
# Copied calckey-0.1.4.tgz to path_to_your_new_folder
# Copied caliper-0.1.7.tgz to path_to_your_new_folder
# Copied camo-0.1.1.tgz to path_to_your_new_folder
# Copied camunda-bpm-platform-7.6.7.tgz to path_to_your_new_folder
# Copied camunda-platform-8.3.1.tgz to path_to_your_new_folder
# Copied canal-server-0.1.2.tgz to path_to_your_new_folder
# Copied capa-vpc-peering-operator-v2023.10.18.tgz to path_to_your_new_folder
# Copied capsule-0.5.2.tgz to path_to_your_new_folder
# Copied capsule-proxy-0.5.0.tgz to path_to_your_new_folder
# Copied capsule-rancher-addon-0.1.1.tgz to path_to_your_new_folder
# Copied carbonetes-analyzer-1.0.6.tgz to path_to_your_new_folder
# Copied careers-0.0.3.tgz to path_to_your_new_folder
# Copied caretta-0.0.16.tgz to path_to_your_new_folder
# Copied cassandra-10.6.2.tgz to path_to_your_new_folder
# Copied castlemock-2.0.1.tgz to path_to_your_new_folder
# Copied catalog-server-0.4.8.tgz to path_to_your_new_folder
# Copied catalog-srv-0.1.11.tgz to path_to_your_new_folder
# Copied cbo-0.1.0.tgz to path_to_your_new_folder
# Copied ccm-hcloud-1.0.11.tgz to path_to_your_new_folder
# Copied ccm-hcloud-test-0.0.1.tgz to path_to_your_new_folder
# Copied ccm-hetzner-1.1.11.tgz to path_to_your_new_folder
# Copied ccm-hetzner-test-0.0.1.tgz to path_to_your_new_folder
# Copied cctp-0.2.2.tgz to path_to_your_new_folder
# Copied central-saml-logout-0.1.1.tgz to path_to_your_new_folder
# Copied cert-exporter-3.0.1.tgz to path_to_your_new_folder
# Copied cert-manager-istio-controller-0.2.1.tgz to path_to_your_new_folder
# Copied cert-manager-setup-0.2.3.tgz to path_to_your_new_folder
# Copied cert-manager-webhook-ace-v2023.10.18.tgz to path_to_your_new_folder
# Copied cert-manager-webhook-bunny-0.1.1.tgz to path_to_your_new_folder
# Copied cert-manager-webhook-civo-0.4.0.tgz to path_to_your_new_folder
# Copied cert-manager-webhook-namecheap-0.1.2.tgz to path_to_your_new_folder
# Copied cert-manager-webhook-ovh-0.5.1.tgz to path_to_your_new_folder
# Copied cga-directory-connector-1.0.3.tgz to path_to_your_new_folder
# Copied cga-proxy-0.2.10.tgz to path_to_your_new_folder
# Copied chadbot-0.1.38.tgz to path_to_your_new_folder
# Copied changedetection-0.2.0.tgz to path_to_your_new_folder
# Copied channels-1.1.0.tgz to path_to_your_new_folder
# Copied charon-relay-0.1.5.tgz to path_to_your_new_folder
# Copied chart-release-sample-v2.1.17.tgz to path_to_your_new_folder
# Copied chartmuseum-1.1.7.tgz to path_to_your_new_folder
# Copied chatapp-0.1.0.tgz to path_to_your_new_folder
# Copied chatgpt-0.1.2.tgz to path_to_your_new_folder
# Copied che-0.1.5.tgz to path_to_your_new_folder
# Copied checkpointz-0.1.3.tgz to path_to_your_new_folder
# Copied chekr-0.5.1.tgz to path_to_your_new_folder
# Copied cherry-2.0.9.tgz to path_to_your_new_folder
# Copied chivalry-medievalwarfare-2.0.9.tgz to path_to_your_new_folder
# Copied choerodon-admin-2.0.0.tgz to path_to_your_new_folder
# Copied choerodon-asgard-2.0.3.tgz to path_to_your_new_folder
# Copied choerodon-cluster-agent-2.6.2.tgz to path_to_your_new_folder
# Copied choerodon-file-2.0.2.tgz to path_to_your_new_folder
# Copied choerodon-front-2.0.1.tgz to path_to_your_new_folder
# Copied choerodon-front-hzero-2.0.0.tgz to path_to_your_new_folder
# Copied choerodon-gateway-2.0.0.tgz to path_to_your_new_folder
# Copied choerodon-iam-2.0.8.tgz to path_to_your_new_folder
# Copied choerodon-message-2.0.4.tgz to path_to_your_new_folder
# Copied choerodon-monitor-2.0.1.tgz to path_to_your_new_folder
# Copied choerodon-oauth-2.0.3.tgz to path_to_your_new_folder
# Copied choerodon-platform-2.0.3.tgz to path_to_your_new_folder
# Copied choerodon-register-2.0.0.tgz to path_to_your_new_folder
# Copied choerodon-swagger-2.0.0.tgz to path_to_your_new_folder
# Copied chowdown-2.0.9.tgz to path_to_your_new_folder
# Copied chromium-2.0.16.tgz to path_to_your_new_folder
# Copied chromium-desktop-g3-2.0.15.tgz to path_to_your_new_folder
# Copied chronograf-2.0.13.tgz to path_to_your_new_folder
# Copied ciao-2.0.12.tgz to path_to_your_new_folder
# Copied cifs-linux-0.1.6.tgz to path_to_your_new_folder
# Copied cilium-1.14.3.tgz to path_to_your_new_folder
# Copied cinnyapp-0.1.1.tgz to path_to_your_new_folder
# Copied circleci-runner-0.1.1.tgz to path_to_your_new_folder
# Copied citadel-forgedwithfire-2.0.9.tgz to path_to_your_new_folder
# Copied ckan-0.0.26.tgz to path_to_your_new_folder
# Copied classification-4.11.0.tgz to path_to_your_new_folder
# Copied cle-0.2.7.tgz to path_to_your_new_folder
# Copied cleanarr-2.0.10.tgz to path_to_your_new_folder
# Copied clickhouse-exporter-0.1.1.tgz to path_to_your_new_folder
# Copied cloud-connector-2022.4.3.tgz to path_to_your_new_folder
# Copied cloud-portal-0.4.1.tgz to path_to_your_new_folder
# Copied cloudbeaver-2.0.16.tgz to path_to_your_new_folder
# Copied cloudcioperator-0.1.0.tgz to path_to_your_new_folder
# Copied cloudcmd-0.0.3.tgz to path_to_your_new_folder
# Copied cloudcommander-2.0.12.tgz to path_to_your_new_folder
# Copied cloudcore-0.1.0.tgz to path_to_your_new_folder
# Copied cloudflare-exporter-0.1.9.tgz to path_to_your_new_folder
# Copied cloudflare-operator-1.2.2.tgz to path_to_your_new_folder
# Copied cloudflare-tunnel-ingress-controller-0.0.8.tgz to path_to_your_new_folder
# Copied cloudflare-tunnel-operator-0.2.0.tgz to path_to_your_new_folder
# Copied cloudhealth-collector-0.1.6.tgz to path_to_your_new_folder
# Copied cloudprober-1.13.8.tgz to path_to_your_new_folder
# Copied cloudquery-27.0.0.tgz to path_to_your_new_folder
# Copied cloudreve-2.0.9.tgz to path_to_your_new_folder
# Copied cloudshell-4.3.0.tgz to path_to_your_new_folder
# Copied cloudwatch-exporter-0.0.6.tgz to path_to_your_new_folder
# Copied cludod-0.0.5.tgz to path_to_your_new_folder
# Copied cluster-connector-v2023.10.18.tgz to path_to_your_new_folder
# Copied cluster-importer-v2023.10.18.tgz to path_to_your_new_folder
# Copied cluster-registry-0.2.12.tgz to path_to_your_new_folder
# Copied cluster-ui-v2023.10.18.tgz to path_to_your_new_folder
# Copied clustercontrol-0.6.0.tgz to path_to_your_new_folder
# Copied cmseek-4.3.0.tgz to path_to_your_new_folder
# Copied cmsms-0.1.4.tgz to path_to_your_new_folder
# Copied cnp-controller-0.0.3.tgz to path_to_your_new_folder
# Copied cockpit-1.9.3.tgz to path_to_your_new_folder
# Copied cockroachdb-11.2.1.tgz to path_to_your_new_folder
# Copied code-repo-service-2.0.7.tgz to path_to_your_new_folder
# Copied code-server-1.0.3.tgz to path_to_your_new_folder
# Copied codehub-4.1.14.tgz to path_to_your_new_folder
# Copied coder-1.44.2.tgz to path_to_your_new_folder
# Copied codetogether-1.4.11.tgz to path_to_your_new_folder
# Copied codimd-0.1.12.tgz to path_to_your_new_folder
# Copied cole-1.4.2.tgz to path_to_your_new_folder
# Copied collabora-online-14.0.18.tgz to path_to_your_new_folder
# Copied colonysurvival-2.0.9.tgz to path_to_your_new_folder
# Copied commonground-gateway-0.1.7.tgz to path_to_your_new_folder
# Copied commonground-gateway-frontend-0.1.0.tgz to path_to_your_new_folder
# Copied community-operator-0.8.3.tgz to path_to_your_new_folder
# Copied community-solid-server-3.0.0.tgz to path_to_your_new_folder
# Copied companion-0.1.7.tgz to path_to_your_new_folder
# Copied conanexiles-2.0.9.tgz to path_to_your_new_folder
# Copied config-server-helm-chart-0.1.0.tgz to path_to_your_new_folder
# Copied config-syncer-v0.14.2.tgz to path_to_your_new_folder
# Copied configmanager-0.1.0.tgz to path_to_your_new_folder
# Copied confluence-server-3.7.2.tgz to path_to_your_new_folder
# Copied connaisseur-2.2.0.tgz to path_to_your_new_folder
# Copied connectbox-exporter-0.0.3.tgz to path_to_your_new_folder
# Copied conreq-2.0.8.tgz to path_to_your_new_folder
# Copied consensus-monitor-0.1.2.tgz to path_to_your_new_folder
# Copied console-0.7.7.tgz to path_to_your_new_folder
# Copied consumer-0.1.3.tgz to path_to_your_new_folder
# Copied consumer-helm-0.1.0.tgz to path_to_your_new_folder
# Copied contentbridge-1.1.0.tgz to path_to_your_new_folder
# Copied contract-watcher-1.0.4.tgz to path_to_your_new_folder
# Copied convos-2.0.10.tgz to path_to_your_new_folder
# Copied core-keeper-dedicated-server-2.0.9.tgz to path_to_your_new_folder
# Copied corekeeper-2.0.11.tgz to path_to_your_new_folder
# Copied coroot-0.5.6.tgz to path_to_your_new_folder
# Copied coroot-node-agent-0.7.0.tgz to path_to_your_new_folder
# Copied cortex-0.6.0.tgz to path_to_your_new_folder
# Copied cortex-gateway-0.1.8.tgz to path_to_your_new_folder
# Copied cortex-tenant-0.3.2.tgz to path_to_your_new_folder
# Copied cosigned-0.1.23.tgz to path_to_your_new_folder
# Copied cosmo-controller-manager-0.9.0.tgz to path_to_your_new_folder
# Copied cosmo-dashboard-0.9.1.tgz to path_to_your_new_folder
# Copied cost-report-0.7.8.tgz to path_to_your_new_folder
# Copied coturn-0.8.4.tgz to path_to_your_new_folder
# Copied couchbase-cluster-0.1.2.tgz to path_to_your_new_folder
# Copied couchbase-operator-2.50.4.tgz to path_to_your_new_folder
# Copied counterstrike2d-2.0.9.tgz to path_to_your_new_folder
# Copied coupon-store-3.0.23.tgz to path_to_your_new_folder
# Copied cowyo-2.0.9.tgz to path_to_your_new_folder
# Copied cp-helm-charts-0.6.1.tgz to path_to_your_new_folder
# Copied craftopia-2.0.9.tgz to path_to_your_new_folder
# Copied cratedb-2.0.3.tgz to path_to_your_new_folder
# Copied cratedb-adapter-v2-0.2.1.tgz to path_to_your_new_folder
# Copied crauti-0.1.4.tgz to path_to_your_new_folder
# Copied cronjob-1.0.2.tgz to path_to_your_new_folder
# Copied cronjobs-0.1.6.tgz to path_to_your_new_folder
# Copied cryptellation-1.0.2.tgz to path_to_your_new_folder
# Copied crypto-exchanges-gateway-2.0.9.tgz to path_to_your_new_folder
# Copied crypto-watchdog-0.1.0.tgz to path_to_your_new_folder
# Copied cse611-fall-team-onlinescheduler-0.1.0.tgz to path_to_your_new_folder
# Copied csgo-0.2.3.tgz to path_to_your_new_folder
# Copied csi-driver-nfs-0.1.4.tgz to path_to_your_new_folder
# Copied csi-hostpath-driver-0.7.0.tgz to path_to_your_new_folder
# Copied csi-vault-v0.3.0.tgz to path_to_your_new_folder
# Copied cso-proxy-0.1.3.tgz to path_to_your_new_folder
# Copied cssource-2.0.9.tgz to path_to_your_new_folder
# Copied cstrike1-6-2.0.9.tgz to path_to_your_new_folder
# Copied cstrikeconditionzero-2.0.9.tgz to path_to_your_new_folder
# Copied ctk-walkthrough-0.1.0.tgz to path_to_your_new_folder
# Copied ctlog-0.2.47.tgz to path_to_your_new_folder
# Copied ctms-0.1.7.tgz to path_to_your_new_folder
# Copied cubestore-0.9.4.tgz to path_to_your_new_folder
# Copied cups-server-3.0.21.tgz to path_to_your_new_folder
# Copied custom-cron-1.0.0.tgz to path_to_your_new_folder
# Copied cyber-center-2022.4.2.tgz to path_to_your_new_folder
# Copied daemonset-0.3.2.tgz to path_to_your_new_folder
# Copied dagster-1.5.7.tgz to path_to_your_new_folder
# Copied dagster-cloud-agent-1.5.7.tgz to path_to_your_new_folder
# Copied dagster-user-deployments-1.5.7.tgz to path_to_your_new_folder
# Copied dailynotes-2.0.9.tgz to path_to_your_new_folder
# Copied damselfly-2.0.13.tgz to path_to_your_new_folder
# Copied dao-2048-1.4.1.tgz to path_to_your_new_folder
# Copied darktable-5.0.13.tgz to path_to_your_new_folder
# Copied dashmachine-2.0.9.tgz to path_to_your_new_folder
# Copied dashy-0.1.3.tgz to path_to_your_new_folder
# Copied dask-kubernetes-operator-2023.10.0.tgz to path_to_your_new_folder
# Copied dast-operator-0.3.2.tgz to path_to_your_new_folder
# Copied data-import-0.1.12.tgz to path_to_your_new_folder
# Copied database-0.12.0.tgz to path_to_your_new_folder
# Copied databend-meta-0.6.1.tgz to path_to_your_new_folder
# Copied databend-query-0.5.1.tgz to path_to_your_new_folder
# Copied datacube-ows-0.19.0.tgz to path_to_your_new_folder
# Copied datacube-wps-0.9.0.tgz to path_to_your_new_folder
# Copied datadog-2.4.23.tgz to path_to_your_new_folder
# Copied datadog-apm-0.0.12.tgz to path_to_your_new_folder
# Copied datadog-controller-1.1.tgz to path_to_your_new_folder
# Copied datahub-0.3.8.tgz to path_to_your_new_folder
# Copied datapusher-1.0.0.tgz to path_to_your_new_folder
# Copied dataspace-connector-0.0.3.tgz to path_to_your_new_folder
# Copied datawolf-1.0.1.tgz to path_to_your_new_folder
# Copied dayofdefeatsource-2.0.9.tgz to path_to_your_new_folder
# Copied daysofwar-2.0.9.tgz to path_to_your_new_folder
# Copied dayz-2.0.9.tgz to path_to_your_new_folder
# Copied db-backup-0.1.0.tgz to path_to_your_new_folder
# Copied db-operator-0.1.0.tgz to path_to_your_new_folder
# Copied dbdump-0.0.10.tgz to path_to_your_new_folder
# Copied dbmate-1.0.0.tgz to path_to_your_new_folder
# Copied ddclient-0.2.0.tgz to path_to_your_new_folder
# Copied ddns-kubernetes-controller-0.1.0.tgz to path_to_your_new_folder
# Copied ddns-route53-2.0.10.tgz to path_to_your_new_folder
# Copied deadman-switch-0.0.2.tgz to path_to_your_new_folder
# Copied debian-0.0.1.tgz to path_to_your_new_folder
# Copied debian-apt-mirror-2.0.9.tgz to path_to_your_new_folder
# Copied debian-bullseye-2.1.8.tgz to path_to_your_new_folder
# Copied deckard-0.0.26.tgz to path_to_your_new_folder
# Copied deepfence-console-2.0.2.tgz to path_to_your_new_folder
# Copied deepflow-6.3.013.tgz to path_to_your_new_folder
# Copied default-chart-3.0.7.tgz to path_to_your_new_folder
# Copied dega-0.11.3.tgz to path_to_your_new_folder
# Copied dega-server-0.1.0.tgz to path_to_your_new_folder
# Copied deis-workflow-0.1.0.tgz to path_to_your_new_folder
# Copied delta-sharing-server-1.2.1.tgz to path_to_your_new_folder
# Copied demo-0.1.0.tgz to path_to_your_new_folder
# Copied demo-model-chart-2.0.0.tgz to path_to_your_new_folder
# Copied demo-v3-0.1.0.tgz to path_to_your_new_folder
# Copied demo-v4-0.1.0.tgz to path_to_your_new_folder
# Copied demo-workflows-1.3.0.tgz to path_to_your_new_folder
# Copied demory-0.7.0.tgz to path_to_your_new_folder
# Copied deploy-0.1.0.tgz to path_to_your_new_folder
# Copied deploy-ui-v2023.10.18.tgz to path_to_your_new_folder
# Copied dev-code-server-0.0.4.tgz to path_to_your_new_folder
# Copied dev-feed-2.4.0.tgz to path_to_your_new_folder
# Copied devlake-1.0.4.tgz to path_to_your_new_folder
# Copied devops-service-business-2.0.13.tgz to path_to_your_new_folder
# Copied devpod-pro-3.3.2.tgz to path_to_your_new_folder
# Copied devportal-admin-ui-0.1.0.tgz to path_to_your_new_folder
# Copied dex-k8s-0.2.1.tgz to path_to_your_new_folder
# Copied dgraph-0.2.2.tgz to path_to_your_new_folder
# Copied dgraph-lambda-0.0.2.tgz to path_to_your_new_folder
# Copied digdag-0.5.2.tgz to path_to_your_new_folder
# Copied digital-mobius-0.1.4.tgz to path_to_your_new_folder
# Copied dinsro-0.1.7.tgz to path_to_your_new_folder
# Copied directus-0.7.31.tgz to path_to_your_new_folder
# Copied discord-bot-0.0.1.tgz to path_to_your_new_folder
# Copied discovery-service-0.4.0.tgz to path_to_your_new_folder
# Copied ditto-operator-0.3.0.tgz to path_to_your_new_folder
# Copied django-0.1.0.tgz to path_to_your_new_folder
# Copied dnation-kubernetes-jsonnet-translator-1.0.1.tgz to path_to_your_new_folder
# Copied dnation-kubernetes-linter-0.1.2.tgz to path_to_your_new_folder
# Copied dnation-kubernetes-monitoring-stack-3.2.0.tgz to path_to_your_new_folder
# Copied dnation-ping-0.1.9.tgz to path_to_your_new_folder
# Copied dns-doh-companion-2.0.13.tgz to path_to_your_new_folder
# Copied dns-proxy-v2023.10.18.tgz to path_to_your_new_folder
# Copied dns-sync-0.1.0.tgz to path_to_your_new_folder
# Copied docker-auth-0.1.1.tgz to path_to_your_new_folder
# Copied docker-certs-ca-installer-1.0.0.tgz to path_to_your_new_folder
# Copied docker-hub-rate-limit-exporter-0.3.0.tgz to path_to_your_new_folder
# Copied docker-hub-rss-2.0.10.tgz to path_to_your_new_folder
# Copied docker-in-docker-0.0.3.tgz to path_to_your_new_folder
# Copied docker-machine-operator-v2023.10.18.tgz to path_to_your_new_folder
# Copied docker-mailserver-2.1.0.tgz to path_to_your_new_folder
# Copied docker-registry-1.9.9.tgz to path_to_your_new_folder
# Copied docker-registry-browser-0.1.2.tgz to path_to_your_new_folder
# Copied docker-registry-gc-0.1.9.tgz to path_to_your_new_folder
# Copied docker-registry-mirror-1.10.3.tgz to path_to_your_new_folder
# Copied docker-registry-proxy-0.0.9.tgz to path_to_your_new_folder
# Copied dockerhub-exporter-1.2.0.tgz to path_to_your_new_folder
# Copied dockerregistry-2.0.11.tgz to path_to_your_new_folder
# Copied docs-0.2.0.tgz to path_to_your_new_folder
# Copied docspell-3.0.25.tgz to path_to_your_new_folder
# Copied doggo-4.3.0.tgz to path_to_your_new_folder
# Copied domain-exporter-0.1.0.tgz to path_to_your_new_folder
# Copied dora-0.0.3.tgz to path_to_your_new_folder
# Copied dotstatsuite-0.2.8.tgz to path_to_your_new_folder
# Copied dregsy-0.1.4.tgz to path_to_your_new_folder
# Copied drone-0.7.12.tgz to path_to_your_new_folder
# Copied drone-kubernetes-secrets-0.1.4.tgz to path_to_your_new_folder
# Copied drone-runner-docker-0.6.1.tgz to path_to_your_new_folder
# Copied drone-runner-kube-0.1.10.tgz to path_to_your_new_folder
# Copied dropbox-by-otherguy-2.0.9.tgz to path_to_your_new_folder
# Copied dshackle-0.1.1.tgz to path_to_your_new_folder
# Copied dsmr-reader-6.4.0.tgz to path_to_your_new_folder
# Copied duckling-1.1.5.tgz to path_to_your_new_folder
# Copied dugtrio-0.0.1.tgz to path_to_your_new_folder
# Copied dummy-nginx-1.0.3.tgz to path_to_your_new_folder
# Copied dummy-nginx-html-1.0.1.tgz to path_to_your_new_folder
# Copied dummy-ssh-4.3.0.tgz to path_to_your_new_folder
# Copied duoauthproxy-radius-simple-0.1.0.tgz to path_to_your_new_folder
# Copied dupeguru-3.0.10.tgz to path_to_your_new_folder
# Copied duplicacy-2.0.11.tgz to path_to_your_new_folder
# Copied dvblink-2.0.9.tgz to path_to_your_new_folder
# Copied dynamodb-0.1.27.tgz to path_to_your_new_folder
# Copied dynamodb-local-1.0.0.tgz to path_to_your_new_folder
# Copied dynatrace-operator-0.14.1.tgz to path_to_your_new_folder
# Copied e2g-1.2.3.tgz to path_to_your_new_folder
# Copied ebpf-exporter-0.3.0.tgz to path_to_your_new_folder
# Copied echoserver-0.1.0.tgz to path_to_your_new_folder
# Copied eck-exporter-1.3.0.tgz to path_to_your_new_folder
# Copied ecodms-2.0.9.tgz to path_to_your_new_folder
# Copied ecowitt-exporter-0.5.0.tgz to path_to_your_new_folder
# Copied ecr-cleaner-0.1.2+2e2ae03.tgz to path_to_your_new_folder
# Copied ecr-exporter-0.2.4.tgz to path_to_your_new_folder
# Copied ecr-proxy-0.2.9.tgz to path_to_your_new_folder
# Copied ecs-inventory-0.0.4.tgz to path_to_your_new_folder
# Copied edge-caiasoft-0.1.32.tgz to path_to_your_new_folder
# Copied edge-connexion-0.1.5.tgz to path_to_your_new_folder
# Copied edge-dematic-0.1.33.tgz to path_to_your_new_folder
# Copied edge-inn-reach-0.1.4.tgz to path_to_your_new_folder
# Copied edge-ncip-0.1.28.tgz to path_to_your_new_folder
# Copied edge-oai-pmh-0.1.31.tgz to path_to_your_new_folder
# Copied edge-orders-0.1.30.tgz to path_to_your_new_folder
# Copied edge-patron-0.1.28.tgz to path_to_your_new_folder
# Copied edge-rtac-0.1.28.tgz to path_to_your_new_folder
# Copied edge-sftp-0.1.2.tgz to path_to_your_new_folder
# Copied edge-sip2-0.1.28.tgz to path_to_your_new_folder
# Copied edp-argocd-operator-0.2.0.tgz to path_to_your_new_folder
# Copied edp-headlamp-0.11.0.tgz to path_to_your_new_folder
# Copied egagent-0.4.0.tgz to path_to_your_new_folder
# Copied egeria-lineage-4.1.0.tgz to path_to_your_new_folder
# Copied egeria-server-4.3.0.tgz to path_to_your_new_folder
# Copied eks-local-disk-provisioner-0.1.4.tgz to path_to_your_new_folder
# Copied elastalert2-2.14.0.tgz to path_to_your_new_folder
# Copied elasticsearch-8.5.1.tgz to path_to_your_new_folder
# Copied elasticsearch-curator-3.0.1.tgz to path_to_your_new_folder
# Copied elasticsearch-data-0.2.0.tgz to path_to_your_new_folder
# Copied elasticsearch-master-0.3.0.tgz to path_to_your_new_folder
# Copied elasticsearch-umbrella-0.8.12.tgz to path_to_your_new_folder
# Copied elasticsearch5-6.2.2.tgz to path_to_your_new_folder
# Copied electrum-2.0.9.tgz to path_to_your_new_folder
# Copied eleel-0.1.4.tgz to path_to_your_new_folder
# Copied element-im-0.2.16.tgz to path_to_your_new_folder
# Copied elk-0.1.1.tgz to path_to_your_new_folder
# Copied elk-frontend-0.1.9.tgz to path_to_your_new_folder
# Copied email-manager-0.1.22.tgz to path_to_your_new_folder
# Copied emby-sync-2.0.9.tgz to path_to_your_new_folder
# Copied enclave-0.1.1.tgz to path_to_your_new_folder
# Copied enforcer-2022.4.17.tgz to path_to_your_new_folder
# Copied enterprise-kyverno-operator-v0.2.41.tgz to path_to_your_new_folder
# Copied eolicplants-0.1.0.tgz to path_to_your_new_folder
# Copied eoloplants-0.1.0.tgz to path_to_your_new_folder
# Copied errbot-0.0.3.tgz to path_to_your_new_folder
# Copied ersatztv-0.0.6.tgz to path_to_your_new_folder
# Copied eshoponabp-1.0.0.tgz to path_to_your_new_folder
# Copied esm-0.6.0.tgz to path_to_your_new_folder
# Copied etcd-defrag-1.0.6.tgz to path_to_your_new_folder
# Copied eth-faucet-0.1.1.tgz to path_to_your_new_folder
# Copied eth2-fork-mon-0.1.2.tgz to path_to_your_new_folder
# Copied ethercalc-2.0.9.tgz to path_to_your_new_folder
# Copied ethereum-address-metrics-exporter-0.1.4.tgz to path_to_your_new_folder
# Copied ethereum-metrics-exporter-0.1.4.tgz to path_to_your_new_folder
# Copied ethereum-validator-metrics-exporter-0.0.1.tgz to path_to_your_new_folder
# Copied ethereumjs-0.0.6.tgz to path_to_your_new_folder
# Copied etherpad-0.0.7.tgz to path_to_your_new_folder
# Copied etherproxy-0.1.0.tgz to path_to_your_new_folder
# Copied ethexporter-0.1.5.tgz to path_to_your_new_folder
# Copied ethproxy-0.1.3.tgz to path_to_your_new_folder
# Copied ethstats-0.1.4.tgz to path_to_your_new_folder
# Copied euterpe-3.0.10.tgz to path_to_your_new_folder
# Copied evam-0.7.2.tgz to path_to_your_new_folder
# Copied evc-documentation-webapp-0.2.0.tgz to path_to_your_new_folder
# Copied eve-member-mailer-1.0.0.tgz to path_to_your_new_folder
# Copied eve-rails-application-1.3.4.tgz to path_to_your_new_folder
# Copied event-generator-0.3.1.tgz to path_to_your_new_folder
# Copied eventrouter-0.4.3.tgz to path_to_your_new_folder
# Copied events-exporter-0.0.4.tgz to path_to_your_new_folder
# Copied evi-consul-0.8.3.tgz to path_to_your_new_folder
# Copied evi-kes-0.8.4.tgz to path_to_your_new_folder
# Copied example-0.1.2.tgz to path_to_your_new_folder
# Copied example-chart-0.9.5.tgz to path_to_your_new_folder
# Copied example-dev-tools-0.2.8.tgz to path_to_your_new_folder
# Copied example-helm-chart-0.1.0.tgz to path_to_your_new_folder
# Copied excalidraw-0.1.1.tgz to path_to_your_new_folder
# Copied exoscale-cloud-controller-manager-0.2.4.tgz to path_to_your_new_folder
# Copied explainshell-2.0.9.tgz to path_to_your_new_folder
# Copied explorer-0.2.15.tgz to path_to_your_new_folder
# Copied exposr-0.11.0.tgz to path_to_your_new_folder
# Copied exposurelog-0.2.1.tgz to path_to_your_new_folder
# Copied extended-ceph-exporter-1.3.2.tgz to path_to_your_new_folder
# Copied extendeddaemonset-v0.3.0.tgz to path_to_your_new_folder
# Copied external-dns-1.13.1.tgz to path_to_your_new_folder
# Copied external-dns-host-network-0.0.12.tgz to path_to_your_new_folder
# Copied external-dns-operator-v2023.10.1.tgz to path_to_your_new_folder
# Copied external-ip-2.0.9.tgz to path_to_your_new_folder
# Copied extractor-0.3.5.tgz to path_to_your_new_folder
# Copied facade-srv-0.1.16.tgz to path_to_your_new_folder
# Copied factorio-server-charts-1.2.5.tgz to path_to_your_new_folder
# Copied factorioservermanager-2.0.9.tgz to path_to_your_new_folder
# Copied facturascripts-2.0.9.tgz to path_to_your_new_folder
# Copied fahclient-2.6.0.tgz to path_to_your_new_folder
# Copied faktory-0.12.3.tgz to path_to_your_new_folder
# Copied falco-2.4.6.tgz to path_to_your_new_folder
# Copied falco-exporter-0.9.7.tgz to path_to_your_new_folder
# Copied falco-ui-server-v2023.10.1.tgz to path_to_your_new_folder
# Copied falcosidekick-0.7.8.tgz to path_to_your_new_folder
# Copied fancyindex-3.0.8.tgz to path_to_your_new_folder
# Copied fargate-sidecar-injector-0.1.5.tgz to path_to_your_new_folder
# Copied farmos-2.0.14.tgz to path_to_your_new_folder
# Copied fastai-7.1.0.tgz to path_to_your_new_folder
# Copied fastcom-mqtt-2.0.9.tgz to path_to_your_new_folder
# Copied fauceth-0.2.3.tgz to path_to_your_new_folder
# Copied fdi-dotstatsuite-config-0.2.0.tgz to path_to_your_new_folder
# Copied fdi-dotstatsuite-de-0.2.0.tgz to path_to_your_new_folder
# Copied fdi-dotstatsuite-de-dv-0.3.0.tgz to path_to_your_new_folder
# Copied fdi-dotstatsuite-dlm-0.3.1.tgz to path_to_your_new_folder
# Copied fdi-dotstatsuite-sfs-solr-1.0.1.tgz to path_to_your_new_folder
# Copied featureform-0.10.2.tgz to path_to_your_new_folder
# Copied featurehub-4.0.5.tgz to path_to_your_new_folder
# Copied fediblockhole-0.1.0.tgz to path_to_your_new_folder
# Copied fenrus-2.0.9.tgz to path_to_your_new_folder
# Copied ferdi-client-2.0.9.tgz to path_to_your_new_folder
# Copied ffmpeg-mkvdts2ac3-2.0.9.tgz to path_to_your_new_folder
# Copied ffuf-4.3.0.tgz to path_to_your_new_folder
# Copied fhir-server-0.9.1.tgz to path_to_your_new_folder
# Copied file-system-ms-helm-chart-0.1.0.tgz to path_to_your_new_folder
# Copied filebeat-8.5.1.tgz to path_to_your_new_folder
# Copied filebot-bot-0.0.9.tgz to path_to_your_new_folder
# Copied filebrowser-1.0.0.tgz to path_to_your_new_folder
# Copied filegator-2.0.9.tgz to path_to_your_new_folder
# Copied filerun-6.0.21.tgz to path_to_your_new_folder
# Copied fileshelter-2.0.11.tgz to path_to_your_new_folder
# Copied firefly-0.3.7.tgz to path_to_your_new_folder
# Copied firefly-iii-0.3.0.tgz to path_to_your_new_folder
# Copied fireflyiii-data-importer-2.0.8.tgz to path_to_your_new_folder
# Copied firefox-browser-0.1.1.tgz to path_to_your_new_folder
# Copied firefox-desktop-g3-2.0.17.tgz to path_to_your_new_folder
# Copied fireshare-2.0.11.tgz to path_to_your_new_folder
# Copied first-mate-1.0.5.tgz to path_to_your_new_folder
# Copied fission-all-v1.19.0.tgz to path_to_your_new_folder
# Copied fistfuloffrags-2.0.9.tgz to path_to_your_new_folder
# Copied fivem-2.0.8.tgz to path_to_your_new_folder
# Copied flagsmith-0.1.5.tgz to path_to_your_new_folder
# Copied flame-2.0.9.tgz to path_to_your_new_folder
# Copied flanksource-ui-1.0.468.tgz to path_to_your_new_folder
# Copied flaresolverr-0.0.3.tgz to path_to_your_new_folder
# Copied flashpaper-3.0.6.tgz to path_to_your_new_folder
# Copied flextv-2.0.9.tgz to path_to_your_new_folder
# Copied flink-operator-0.1.1.tgz to path_to_your_new_folder
# Copied floritest-0.1.0.tgz to path_to_your_new_folder
# Copied flowmanager-0.6.0.tgz to path_to_your_new_folder
# Copied flows-0.6.0.tgz to path_to_your_new_folder
# Copied fluent-bit-aggregator-0.10.0.tgz to path_to_your_new_folder
# Copied fluent-bit-collector-0.7.0.tgz to path_to_your_new_folder
# Copied fluent-operator-2.5.0.tgz to path_to_your_new_folder
# Copied fluentd-aggregator-4.0.0.tgz to path_to_your_new_folder
# Copied fluentd-elasticsearch-13.11.0.tgz to path_to_your_new_folder
# Copied fluentd-papertrail-0.2.2.tgz to path_to_your_new_folder
# Copied fluttercoin-wallet-2.0.9.tgz to path_to_your_new_folder
# Copied flux-notifier-0.0.7.tgz to path_to_your_new_folder
# Copied fluxcd-webui-0.0.2.tgz to path_to_your_new_folder
# Copied flyway-operator-0.1.1.tgz to path_to_your_new_folder
# Copied fmd2-wine-2.0.9.tgz to path_to_your_new_folder
# Copied focalboard-0.5.0.tgz to path_to_your_new_folder
# Copied fogproject-2.0.9.tgz to path_to_your_new_folder
# Copied foldingathome-0.1.0.tgz to path_to_your_new_folder
# Copied foo-0.1.1.tgz to path_to_your_new_folder
# Copied forecastle-v1.0.132.tgz to path_to_your_new_folder
# Copied forkmon-0.1.4.tgz to path_to_your_new_folder
# Copied forky-0.1.1.tgz to path_to_your_new_folder
# Copied forward-1.3.1.tgz to path_to_your_new_folder
# Copied fossology-0.2.0.tgz to path_to_your_new_folder
# Copied fotosho-2.0.9.tgz to path_to_your_new_folder
# Copied freecad-desktop-g3-2.0.9.tgz to path_to_your_new_folder
# Copied frigate-8.2.2.tgz to path_to_your_new_folder
# Copied frinx-arango-config-3.0.0.tgz to path_to_your_new_folder
# Copied frinx-frontend-3.1.2.tgz to path_to_your_new_folder
# Copied frinx-machine-0.4.87.tgz to path_to_your_new_folder
# Copied frontend-0.1.7.tgz to path_to_your_new_folder
# Copied frpc-1.0.1.tgz to path_to_your_new_folder
# Copied frps-1.0.1.tgz to path_to_your_new_folder
# Copied fsm-2.0.8.tgz to path_to_your_new_folder
# Copied fulcio-2.3.13.tgz to path_to_your_new_folder
# Copied fulfillment-srv-0.1.6.tgz to path_to_your_new_folder
# Copied futtertrog-1.7.0.tgz to path_to_your_new_folder
# Copied g-cronjob-0.0.6.tgz to path_to_your_new_folder
# Copied galaxy-5.7.6.tgz to path_to_your_new_folder
# Copied ganache-0.1.2.tgz to path_to_your_new_folder
# Copied gangway-1.1.0.tgz to path_to_your_new_folder
# Copied gar-exporter-0.1.1.tgz to path_to_your_new_folder
# Copied garrysmod-2.0.9.tgz to path_to_your_new_folder
# Copied gate-0.1.0.tgz to path_to_your_new_folder
# Copied gateboard-1.8.2.tgz to path_to_your_new_folder
# Copied gateboard-discovery-1.7.3.tgz to path_to_your_new_folder
# Copied gaxy-0.1.0.tgz to path_to_your_new_folder
# Copied gbox-1.0.5.tgz to path_to_your_new_folder
# Copied gcloud-sql-proxy-0.1.0.tgz to path_to_your_new_folder
# Copied gcp-local-ssd-raid-0.1.3.tgz to path_to_your_new_folder
# Copied gcp-quota-exporter-2.0.1.tgz to path_to_your_new_folder
# Copied genea-2.0.9.tgz to path_to_your_new_folder
# Copied generic-app-0.0.17.tgz to path_to_your_new_folder
# Copied genesis-generator-0.2.2.tgz to path_to_your_new_folder
# Copied geo-checker-2.1.1.tgz to path_to_your_new_folder
# Copied geomapfish-0.7.0.tgz to path_to_your_new_folder
# Copied geoserver-cloud-0.0.5.tgz to path_to_your_new_folder
# Copied geoservercloud-0.6.0.tgz to path_to_your_new_folder
# Copied get-cloudflare-logs-0.6.0.tgz to path_to_your_new_folder
# Copied geth-2.3.4.tgz to path_to_your_new_folder
# Copied geth-swap-0.4.1.tgz to path_to_your_new_folder
# Copied ghost-export-to-s3-0.24.1.tgz to path_to_your_new_folder
# Copied git-configmap-sync-1.0.1.tgz to path_to_your_new_folder
# Copied git-repo-0.1.0.tgz to path_to_your_new_folder
# Copied git-repo-scanner-4.3.0.tgz to path_to_your_new_folder
# Copied gitana-1.4.0.tgz to path_to_your_new_folder
# Copied gitea-sonarqube-bot-0.3.4.tgz to path_to_your_new_folder
# Copied github-actions-runner-0.10.3.tgz to path_to_your_new_folder
# Copied github-actions-runner-operator-2.8.1.tgz to path_to_your_new_folder
# Copied github-backup-2.0.8.tgz to path_to_your_new_folder
# Copied github-exporter-1.1.0.tgz to path_to_your_new_folder
# Copied github-prometheus-exporter-0.1.3.tgz to path_to_your_new_folder
# Copied github-rate-limits-prometheus-exporter-0.2.14.tgz to path_to_your_new_folder
# Copied gitlab-agent-1.21.0.tgz to path_to_your_new_folder
# Copied gitlab-agent-permissioned-1.0.9.tgz to path_to_your_new_folder
# Copied gitlab-code-review-notifier-0.1.2.tgz to path_to_your_new_folder
# Copied gitlab-omnibus-0.1.3.tgz to path_to_your_new_folder
# Copied gitlab-runner-0.58.2.tgz to path_to_your_new_folder
# Copied gitlab-runner-operator-1.5.0.tgz to path_to_your_new_folder
# Copied gitlab-service-2.0.1.tgz to path_to_your_new_folder
# Copied gitlab-zoekt-0.8.1.tgz to path_to_your_new_folder
# Copied gitleaks-4.3.0.tgz to path_to_your_new_folder
# Copied gitter-irc-bridge-0.1.1.tgz to path_to_your_new_folder
# Copied gittest-0.1.0.tgz to path_to_your_new_folder
# Copied gitwebhookproxy-v0.2.79.tgz to path_to_your_new_folder
# Copied gke-node-pool-shifter-0.1.0.tgz to path_to_your_new_folder
# Copied gke-preemptible-notifier-0.0.6.tgz to path_to_your_new_folder
# Copied gke-pvm-killer-0.1.3.tgz to path_to_your_new_folder
# Copied gke-upgrade-notification-handler-0.1.1.tgz to path_to_your_new_folder
# Copied glauth-2.0.9.tgz to path_to_your_new_folder
# Copied glider-0.1.5.tgz to path_to_your_new_folder
# Copied glowroot-1.0.10.tgz to path_to_your_new_folder
# Copied go-app-helm-0.1.0.tgz to path_to_your_new_folder
# Copied go-auto-yt-2.0.9.tgz to path_to_your_new_folder
# Copied go-chatgpt-api-0.1.6.tgz to path_to_your_new_folder
# Copied go-hello-world-0.11.1.tgz to path_to_your_new_folder
# Copied go-playground-2.0.9.tgz to path_to_your_new_folder
# Copied go-ratelimit-1.0.7.tgz to path_to_your_new_folder
# Copied goaccess-2.0.8.tgz to path_to_your_new_folder
# Copied goaccess-npm-logs-2.0.13.tgz to path_to_your_new_folder
# Copied goalert-0.0.14.tgz to path_to_your_new_folder
# Copied goblackhole-0.0.4.tgz to path_to_your_new_folder
# Copied godaddy-ddns-2.0.9.tgz to path_to_your_new_folder
# Copied godbox-0.2.0.tgz to path_to_your_new_folder
# Copied gooddata-cn-3.0.0.tgz to path_to_your_new_folder
# Copied google-cloud-storage-backup-2.0.9.tgz to path_to_your_new_folder
# Copied googlephotossync-2.0.15.tgz to path_to_your_new_folder
# Copied gotenberg-0.6.0.tgz to path_to_your_new_folder
# Copied gotosocial-0.4.13.tgz to path_to_your_new_folder
# Copied gpodder-2.0.9.tgz to path_to_your_new_folder
# Copied gpts-0.7.7.tgz to path_to_your_new_folder
# Copied gpu-operator-v1.9.1.tgz to path_to_your_new_folder
# Copied gradle-cache-0.1.5.tgz to path_to_your_new_folder
# Copied gradle-example-1.1.3.tgz to path_to_your_new_folder
# Copied grafana-agent-0.19.1.tgz to path_to_your_new_folder
# Copied grafana-image-renderer-2.0.12.tgz to path_to_your_new_folder
# Copied grafana-matrix-forwarder-1.0.0.tgz to path_to_your_new_folder
# Copied grafana-pdf-exporter-2.1.1.tgz to path_to_your_new_folder
# Copied grafana-ui-server-v2022.06.14.tgz to path_to_your_new_folder
# Copied grafana-v2023.10.18.tgz to path_to_your_new_folder
# Copied grandine-0.1.1.tgz to path_to_your_new_folder
# Copied graphite-exporter-0.1.6.tgz to path_to_your_new_folder
# Copied graphql-gateway-0.1.5.tgz to path_to_your_new_folder
# Copied gravity-init-v1.0.9.tgz to path_to_your_new_folder
# Copied graylog-1.0.0.tgz to path_to_your_new_folder
# Copied gremlin-integrations-0.1.0.tgz to path_to_your_new_folder
# Copied gridcoinwalletgui-2.0.10.tgz to path_to_your_new_folder
# Copied grist-7.0.31.tgz to path_to_your_new_folder
# Copied grocery-beep-1.0.0.tgz to path_to_your_new_folder
# Copied grocy-0.1.1.tgz to path_to_your_new_folder
# Copied group-challenge-1.2.3.tgz to path_to_your_new_folder
# Copied grpc-app-0.1.0.tgz to path_to_your_new_folder
# Copied grpc-server-0.1.5.tgz to path_to_your_new_folder
# Copied gtm-server-container-cluster-0.1.5.tgz to path_to_your_new_folder
# Copied guacamole-1.4.0.tgz to path_to_your_new_folder
# Copied guacamole-client-7.0.25.tgz to path_to_your_new_folder
# Copied guide2go-2.0.10.tgz to path_to_your_new_folder
# Copied h2o-3-44.0.2.tgz to path_to_your_new_folder
# Copied h5ai-2.0.9.tgz to path_to_your_new_folder
# Copied habridge-4.0.18.tgz to path_to_your_new_folder
# Copied halflife2deathmatch-2.0.9.tgz to path_to_your_new_folder
# Copied hallo-wereld-0.1.0.tgz to path_to_your_new_folder
# Copied hapi-fhir-0.1.0.tgz to path_to_your_new_folder
# Copied haproxy-2.5.0.tgz to path_to_your_new_folder
# Copied haproxy-ingress-0.14.5.tgz to path_to_your_new_folder
# Copied harbor-scanner-sysdig-secure-0.5.1.tgz to path_to_your_new_folder
# Copied harbor-scanner-trivy-0.17.0.tgz to path_to_your_new_folder
# Copied harness-delegate-ng-1.0.14.tgz to path_to_your_new_folder
# Copied harperdb-0.1.0.tgz to path_to_your_new_folder
# Copied hassconfigurator-2.0.10.tgz to path_to_your_new_folder
# Copied hastebin-2.0.9.tgz to path_to_your_new_folder
# Copied hasura-3.0.0.tgz to path_to_your_new_folder
# Copied haven-dashboard-0.1.1.tgz to path_to_your_new_folder
# Copied hawk-1.1.1.tgz to path_to_your_new_folder
# Copied hawkbit-1.5.0.tgz to path_to_your_new_folder
# Copied hawkbit-operator-0.1.4.tgz to path_to_your_new_folder
# Copied hazelcast-5.8.11.tgz to path_to_your_new_folder
# Copied hazelcast-enterprise-5.10.10.tgz to path_to_your_new_folder
# Copied hazelcast-jet-1.17.1.tgz to path_to_your_new_folder
# Copied hazelcast-jet-enterprise-1.17.1.tgz to path_to_your_new_folder
# Copied hazelcast-platform-operator-5.10.0.tgz to path_to_your_new_folder
# Copied hcloud-exporter-2.2.0.tgz to path_to_your_new_folder
# Copied hcloud-fip-controller-0.2.5.tgz to path_to_your_new_folder
# ...
# Copied testappchart-0.1.0.tgz to path_to_your_new_folder
# Copied testhub-0.1.4.tgz to path_to_your_new_folder
# Copied testkube-1.15.25.tgz to path_to_your_new_folder
# Copied testkube-api-1.15.18.tgz to path_to_your_new_folder
# Copied testkube-dashboard-1.14.2.tgz to path_to_your_new_folder
# Copied testkube-operator-1.15.3.tgz to path_to_your_new_folder
# Copied testnet-faucet-0.1.2.tgz to path_to_your_new_folder
# Copied testnet-homepage-0.2.2.tgz to path_to_your_new_folder
# Copied testwebapp-0.1.1.tgz to path_to_your_new_folder
# Copied tetragon-1.0.0.tgz to path_to_your_new_folder
# Copied tezos-node-1.0.0.tgz to path_to_your_new_folder
# Copied tftp-1.0.0.tgz to path_to_your_new_folder
# Copied tfy-agent-0.2.12.tgz to path_to_your_new_folder
# Copied tfy-buildkitd-service-0.1.1.tgz to path_to_your_new_folder
# Copied thanhvt27-lab-k8s-0.1.4.tgz to path_to_your_new_folder
# Copied thanos-operator-0.3.7.tgz to path_to_your_new_folder
# Copied theforest-2.0.9.tgz to path_to_your_new_folder
# Copied thermite-0.1.17.tgz to path_to_your_new_folder
# Copied thingsboard-0.1.2.tgz to path_to_your_new_folder
# Copied third-0.1.0.tgz to path_to_your_new_folder
# Copied thumba-0.0.7.tgz to path_to_your_new_folder
# Copied thunderbird-2.0.12.tgz to path_to_your_new_folder
# Copied thunderdome-planning-poker-0.1.1.tgz to path_to_your_new_folder
# Copied tigera-operator-2.8.0.tgz to path_to_your_new_folder
# Copied timetagger-2.0.14.tgz to path_to_your_new_folder
# Copied tinyproxy-exporter-0.1.0.tgz to path_to_your_new_folder
# Copied tmdb-0.2.3.tgz to path_to_your_new_folder
# Copied todo-api-0.1.0.tgz to path_to_your_new_folder
# Copied todo-app-1.1.3.tgz to path_to_your_new_folder
# Copied tokenexporter-0.1.6.tgz to path_to_your_new_folder
# Copied tonido-2.0.9.tgz to path_to_your_new_folder
# Copied topology-discovery-2.4.0.tgz to path_to_your_new_folder
# Copied topologyspread-webhook-0.1.0.tgz to path_to_your_new_folder
# Copied topolvm-12.1.0.tgz to path_to_your_new_folder
# Copied tor-snowflake-proxy-0.5.0.tgz to path_to_your_new_folder
# Copied toranku-1.0.0.tgz to path_to_your_new_folder
# Copied torznab-atomohd-0.0.3.tgz to path_to_your_new_folder
# Copied toxiproxy-1.3.8.tgz to path_to_your_new_folder
# Copied tracee-0.18.1.tgz to path_to_your_new_folder
# Copied tracetest-0.2.89.tgz to path_to_your_new_folder
# Copied tracker-0.3.5.tgz to path_to_your_new_folder
# Copied tracks-2.0.14.tgz to path_to_your_new_folder
# Copied traefik-25.0.0.tgz to path_to_your_new_folder
# Copied trafficlight-api-0.1.1.tgz to path_to_your_new_folder
# Copied training-operator-1.2.2.tgz to path_to_your_new_folder
# Copied traktarr-2.0.10.tgz to path_to_your_new_folder
# Copied trango-2.0.9.tgz to path_to_your_new_folder
# Copied transmission-openvpn-2.5.0.tgz to path_to_your_new_folder
# Copied tree-0.1.10.tgz to path_to_your_new_folder
# Copied trickster-v2023.10.1.tgz to path_to_your_new_folder
# Copied trifid-2.0.2.tgz to path_to_your_new_folder
# Copied triggers-0.4.0.tgz to path_to_your_new_folder
# Copied trilium-0.1.0.tgz to path_to_your_new_folder
# Copied trillian-0.2.17.tgz to path_to_your_new_folder
# Copied trino-1.23.4.tgz to path_to_your_new_folder
# Copied trino-exporter-0.0.11.tgz to path_to_your_new_folder
# Copied trino-loadbalancer-0.2.8.tgz to path_to_your_new_folder
# Copied trivy-0.7.0.tgz to path_to_your_new_folder
# Copied trivy-operator-polr-adapter-0.7.0.tgz to path_to_your_new_folder
# Copied trivy-sbom-4.3.0.tgz to path_to_your_new_folder
# Copied trivy-server-0.1.0.tgz to path_to_your_new_folder
# Copied troddit-2.0.10.tgz to path_to_your_new_folder
# Copied tronador-0.0.1.tgz to path_to_your_new_folder
# Copied truenas-csp-1.1.5.tgz to path_to_your_new_folder
# Copied ts-dnsserver-2.0.20.tgz to path_to_your_new_folder
# Copied tsa-1.0.1.tgz to path_to_your_new_folder
# Copied tubearchivist-es-2.0.11.tgz to path_to_your_new_folder
# Copied tubearchivist-redisjson-2.0.14.tgz to path_to_your_new_folder
# Copied tubesync-2.0.12.tgz to path_to_your_new_folder
# Copied turborepo-remote-cache-1.1.1.tgz to path_to_your_new_folder
# Copied tusd-0.1.0.tgz to path_to_your_new_folder
# Copied tvhproxy-2.0.9.tgz to path_to_your_new_folder
# Copied twitch-predictions-recorder-0.1.0.tgz to path_to_your_new_folder
# Copied twonky-server-2.0.18.tgz to path_to_your_new_folder
# Copied tyk-data-plane-1.0.0.tgz to path_to_your_new_folder
# Copied tyk-gateway-1.1.0.tgz to path_to_your_new_folder
# Copied tyk-headless-0.14.1.tgz to path_to_your_new_folder
# Copied tyk-hybrid-0.14.1.tgz to path_to_your_new_folder
# Copied tyk-oss-1.1.0.tgz to path_to_your_new_folder
# Copied tyk-pro-0.14.1.tgz to path_to_your_new_folder
# Copied tyk-pump-1.1.0.tgz to path_to_your_new_folder
# Copied typecho-7.0.21.tgz to path_to_your_new_folder
# Copied typemill-0.1.6.tgz to path_to_your_new_folder
# Copied typesense-0.1.6.tgz to path_to_your_new_folder
# Copied typo3-1.18.2.tgz to path_to_your_new_folder
# Copied typo3scan-4.3.0.tgz to path_to_your_new_folder
# Copied ubooquity-0.1.1.tgz to path_to_your_new_folder
# Copied ubuntu-xrdp-2.1.7.tgz to path_to_your_new_folder
# Copied ucloud-exporter-0.1.1.tgz to path_to_your_new_folder
# Copied umami-0.0.1.tgz to path_to_your_new_folder
# Copied umsapp-1.0.0.tgz to path_to_your_new_folder
# Copied unbound-1.15.3.tgz to path_to_your_new_folder
# Copied ungoogled-chromium-2.0.9.tgz to path_to_your_new_folder
# Copied uniconfig-5.0.1.tgz to path_to_your_new_folder
# Copied unifi-0.1.3.tgz to path_to_your_new_folder
# Copied unifi-controller-2.4.0.tgz to path_to_your_new_folder
# Copied unifi-poller-0.1.0.tgz to path_to_your_new_folder
# Copied uniresource-1.1.1.tgz to path_to_your_new_folder
# Copied universal-media-server-2.0.14.tgz to path_to_your_new_folder
# Copied unleash-3.0.4.tgz to path_to_your_new_folder
# Copied unleash-edge-2.1.0.tgz to path_to_your_new_folder
# Copied unleash-proxy-0.6.2.tgz to path_to_your_new_folder
# Copied unpoller-0.0.3.tgz to path_to_your_new_folder
# Copied unpubd-1.0.1.tgz to path_to_your_new_folder
# Copied unsafe-https-4.3.0.tgz to path_to_your_new_folder
# Copied upsnap-0.0.2.tgz to path_to_your_new_folder
# Copied upsource-0.1.1.tgz to path_to_your_new_folder
# Copied uptime-bot-1.1.12.tgz to path_to_your_new_folder
# Copied uptime-kuma-0.1.7.tgz to path_to_your_new_folder
# Copied uptrace-1.5.7.tgz to path_to_your_new_folder
# Copied upyun-exporter-0.1.0.tgz to path_to_your_new_folder
# Copied urban-terror-2.0.9.tgz to path_to_your_new_folder
# Copied url-shortener-1.0.2.tgz to path_to_your_new_folder
# Copied url-shortner-charts-1.0.1.tgz to path_to_your_new_folder
# Copied user-component-1.2.0.tgz to path_to_your_new_folder
# Copied user-data-ms-helm-chart-0.1.0.tgz to path_to_your_new_folder
# Copied utcook-2.1.4.tgz to path_to_your_new_folder
# Copied v-rising-2.0.9.tgz to path_to_your_new_folder
# Copied v3-keeper-3.0.7.tgz to path_to_your_new_folder
# Copied v3-monitor-1.0.0.tgz to path_to_your_new_folder
# Copied v3-oracle-3.2.5.tgz to path_to_your_new_folder
# Copied vald-helm-operator-v1.7.8.tgz to path_to_your_new_folder
# Copied vald-v1.7.8.tgz to path_to_your_new_folder
# Copied valetudo-mapper-2.0.9.tgz to path_to_your_new_folder
# Copied validator-monitor-1.0.4.tgz to path_to_your_new_folder
# Copied vals-operator-0.7.7.tgz to path_to_your_new_folder
# Copied vanity-0.3.17.tgz to path_to_your_new_folder
# Copied vault-gcp-secrets-1.15.0.tgz to path_to_your_new_folder
# Copied vault-helm-chart-0.1.0.tgz to path_to_your_new_folder
# Copied vault-operator-1.19.0.tgz to path_to_your_new_folder
# Copied vault-secrets-webhook-1.19.0.tgz to path_to_your_new_folder
# Copied vault-token-injector-3.1.0.tgz to path_to_your_new_folder
# Copied vault-unsealer-0.1.4.tgz to path_to_your_new_folder
# Copied vaulthunters-2.0.9.tgz to path_to_your_new_folder
# Copied vaultwarden-1.0.0.tgz to path_to_your_new_folder
# Copied vcluster-0.16.4.tgz to path_to_your_new_folder
# Copied vcluster-control-plane-3.3.2.tgz to path_to_your_new_folder
# Copied vcluster-eks-0.16.4.tgz to path_to_your_new_folder
# Copied vcluster-k0s-0.16.4.tgz to path_to_your_new_folder
# Copied vcluster-k8s-0.16.4.tgz to path_to_your_new_folder
# Copied vcluster-pro-0.2.0.tgz to path_to_your_new_folder
# Copied vcluster-pro-eks-0.2.0.tgz to path_to_your_new_folder
# Copied vcluster-pro-k0s-0.2.0.tgz to path_to_your_new_folder
# Copied vcluster-pro-k8s-0.2.0.tgz to path_to_your_new_folder
# Copied vcontainer-csi-blockstorage-0.0.13.tgz to path_to_your_new_folder
# Copied vda-0.1.0.tgz to path_to_your_new_folder
# Copied vector-0.28.0.tgz to path_to_your_new_folder
# Copied vector-controller-0.2.3.tgz to path_to_your_new_folder
# Copied vela-core-1.9.7.tgz to path_to_your_new_folder
# Copied vela-workflow-0.6.0.tgz to path_to_your_new_folder
# Copied velero-notifications-1.1.0.tgz to path_to_your_new_folder
# Copied velero-s3-deployment-0.1.1.tgz to path_to_your_new_folder
# Copied venstar2mqtt-2.0.9.tgz to path_to_your_new_folder
# Copied verdaccio-0.7.0.tgz to path_to_your_new_folder
# Copied vernemq-1.6.9.tgz to path_to_your_new_folder
# Copied vertex-2.0.20.tgz to path_to_your_new_folder
# Copied vertica-kafka-scheduler-0.1.3.tgz to path_to_your_new_folder
# Copied vertical-pod-autoscaler-1.4.0.tgz to path_to_your_new_folder
# Copied verzoekregistratiecomponent-1.1.0.tgz to path_to_your_new_folder
# Copied verzoektypecatalogus-1.1.0.tgz to path_to_your_new_folder
# Copied victoria-metrics-agent-0.8.41.tgz to path_to_your_new_folder
# Copied vidcheck-0.5.2.tgz to path_to_your_new_folder
# Copied vintage-story-2.0.9.tgz to path_to_your_new_folder
# Copied virt-manager-2.0.21.tgz to path_to_your_new_folder
# Copied visual-regression-tracker-2.0.1.tgz to path_to_your_new_folder
# Copied vlmcsd-kms-server-2.0.9.tgz to path_to_your_new_folder
# Copied vmonitor-metric-agent-0.3.0.tgz to path_to_your_new_folder
# Copied vmware-rest-proxy-0.1.6.tgz to path_to_your_new_folder
# Copied voice-biometrics-2.0.1.tgz to path_to_your_new_folder
# Copied volantmq-0.1.2.tgz to path_to_your_new_folder
# Copied volsync-0.7.1.tgz to path_to_your_new_folder
# Copied voltha-2.12.10.tgz to path_to_your_new_folder
# Copied voltha-adapter-openolt-2.12.5.tgz to path_to_your_new_folder
# Copied voltha-adapter-openonu-2.12.0.tgz to path_to_your_new_folder
# Copied voltha-adapter-simulated-2.3.2.tgz to path_to_your_new_folder
# Copied voltha-go-controller-0.1.3.tgz to path_to_your_new_folder
# Copied voltha-tracing-2.12.0.tgz to path_to_your_new_folder
# Copied vorta-2.0.9.tgz to path_to_your_new_folder
# Copied voyager-1.1.2.tgz to path_to_your_new_folder
# Copied vpn.tgz to path_to_your_new_folder
# Copied vscode-6.9.0.tgz to path_to_your_new_folder
# Copied vsecm-0.21.3.tgz to path_to_your_new_folder
# Copied vulnerability-operator-0.23.0.tgz to path_to_your_new_folder
# Copied vulnerable-log4j-4.3.0.tgz to path_to_your_new_folder
# Copied waardepapieren-register-1.1.0.tgz to path_to_your_new_folder
# Copied wakapi-0.1.2.tgz to path_to_your_new_folder
# Copied wallabag-0.2.4.tgz to path_to_your_new_folder
# Copied wallarm-ingress-4.8.3.tgz to path_to_your_new_folder
# Copied wallarm-ingress-rc-4.8.4.tgz to path_to_your_new_folder
# Copied wallarm-oob-0.10.9.tgz to path_to_your_new_folder
# Copied wallarm-sidecar-4.8.0.tgz to path_to_your_new_folder
# Copied walletconnect-relay-0.1.2.tgz to path_to_your_new_folder
# Copied watcher-0.4.4.tgz to path_to_your_new_folder
# Copied web-0.1.7.tgz to path_to_your_new_folder
# Copied web-cardinality-0.1.2.tgz to path_to_your_new_folder
# Copied web3-indexer-0.0.15.tgz to path_to_your_new_folder
# Copied webapp-gin-0.1.2.tgz to path_to_your_new_folder
# Copied webdav-0.0.7.tgz to path_to_your_new_folder
# Copied webencryptor-1.1.0.tgz to path_to_your_new_folder
# Copied webhook-broker-chart-0.1.2.tgz to path_to_your_new_folder
# Copied webhook-receiver-2.0.0.tgz to path_to_your_new_folder
# Copied webhook-site-0.0.3.tgz to path_to_your_new_folder
# Copied webhookrelay-operator-0.4.1.tgz to path_to_your_new_folder
# Copied webhooks-0.1.5.tgz to path_to_your_new_folder
# Copied webp-server-2.0.15.tgz to path_to_your_new_folder
# Copied webresourcecatalogus-1.1.0.tgz to path_to_your_new_folder
# Copied website-0.33.0.tgz to path_to_your_new_folder
# Copied wekan-0.1.2.tgz to path_to_your_new_folder
# Copied well-known-1.7.2.tgz to path_to_your_new_folder
# Copied wger-4.0.43.tgz to path_to_your_new_folder
# Copied whatweb-4.3.0.tgz to path_to_your_new_folder
# Copied whitebox-0.0.20.tgz to path_to_your_new_folder
# Copied whoami-1.0.1.tgz to path_to_your_new_folder
# Copied wifi-card-2.0.14.tgz to path_to_your_new_folder
# Copied wiki-2.2.0.tgz to path_to_your_new_folder
# Copied wipeout-rewrite-0.1.0.tgz to path_to_your_new_folder
# Copied wireguard-1.4.2.tgz to path_to_your_new_folder
# Copied wireguard-pia-1.5.3.tgz to path_to_your_new_folder
# Copied wireshark-5.0.0.tgz to path_to_your_new_folder
# Copied witcom-id-generator-1.1.1.tgz to path_to_your_new_folder
# Copied wmbusmeters-1.4.2.tgz to path_to_your_new_folder
# Copied wombat-3.7.0.tgz to path_to_your_new_folder
# Copied woodpecker-0.4.2.tgz to path_to_your_new_folder
# Copied wopiserver-0.9.2.tgz to path_to_your_new_folder
# Copied wordpress-apache-2.1.12.tgz to path_to_your_new_folder
# Copied wordpress-operator-0.12.2.tgz to path_to_your_new_folder
# Copied worker-2.4.0.tgz to path_to_your_new_folder
# Copied workflow-manager-2.0.1.tgz to path_to_your_new_folder
# Copied workflow-service-2.0.3.tgz to path_to_your_new_folder
# Copied workload-operator-0.0.3.tgz to path_to_your_new_folder
# Copied workshop-exercise-0.0.260.tgz to path_to_your_new_folder
# Copied workshop-operator-0.0.38.tgz to path_to_your_new_folder
# Copied world-db-0.1.0.tgz to path_to_your_new_folder
# Copied wpscan-4.3.0.tgz to path_to_your_new_folder
# Copied wuliu-0.0.9.tgz to path_to_your_new_folder
# Copied x509-certificate-exporter-3.10.1.tgz to path_to_your_new_folder
# Copied xatu-0.0.1.tgz to path_to_your_new_folder
# Copied xatu-cannon-0.2.0.tgz to path_to_your_new_folder
# Copied xatu-discovery-0.0.5.tgz to path_to_your_new_folder
# Copied xatu-mimicry-0.0.6.tgz to path_to_your_new_folder
# Copied xatu-sentry-0.0.7.tgz to path_to_your_new_folder
# Copied xatu-server-0.0.10.tgz to path_to_your_new_folder
# Copied xonotic-2.0.9.tgz to path_to_your_new_folder
# Copied xteve-0.1.6.tgz to path_to_your_new_folder
# Copied xware-2.0.9.tgz to path_to_your_new_folder
# Copied xxl-job-admin-1.1.2.tgz to path_to_your_new_folder
# Copied yace-exporter-0.1.0.tgz to path_to_your_new_folder
# Copied yacreaderlibraryserver-2.0.10.tgz to path_to_your_new_folder
# Copied yacy-2.0.15.tgz to path_to_your_new_folder
# Copied yatai-1.1.13.tgz to path_to_your_new_folder
# Copied yatai-deployment-1.1.16.tgz to path_to_your_new_folder
# Copied yatai-image-builder-1.2.12.tgz to path_to_your_new_folder
# Copied yatai-serverless-0.0.9.tgz to path_to_your_new_folder
# Copied yopass-0.7.0.tgz to path_to_your_new_folder
# Copied yourchat-0.1.0.tgz to path_to_your_new_folder
# Copied yourls-2.0.15.tgz to path_to_your_new_folder
# Copied youtube-dl-tiny-grpc-0.1.5.tgz to path_to_your_new_folder
# Copied yugaware-2.19.3.tgz to path_to_your_new_folder
# Copied z80pack-2.0.9.tgz to path_to_your_new_folder
# Copied zabbix-4.0.2.tgz to path_to_your_new_folder
# Copied zahori-postgresql-1.0.1.tgz to path_to_your_new_folder
# Copied zahori-server-1.0.1.tgz to path_to_your_new_folder
# Copied zammad-10.0.4.tgz to path_to_your_new_folder
# Copied zap-4.3.0.tgz to path_to_your_new_folder
# Copied zap-advanced-4.3.0.tgz to path_to_your_new_folder
# Copied zeppelin-0.1.3.tgz to path_to_your_new_folder
# Copied zeus-0.1.12.tgz to path_to_your_new_folder
# Copied zigbee2mqtt-9.4.2.tgz to path_to_your_new_folder
# Copied zinc-0.1.2.tgz to path_to_your_new_folder
# Copied zipkin-2.1.4.tgz to path_to_your_new_folder
# Copied zoneminder-2.0.12.tgz to path_to_your_new_folder
# Copied zoo-0.4.0.tgz to path_to_your_new_folder
# Copied zoo-project-dru-0.0.7.tgz to path_to_your_new_folder
# Copied zoo-project-hpgc-0.0.2.tgz to path_to_your_new_folder
# Copied zoo-project-workshop-0.0.4.tgz to path_to_your_new_folder
# Copied zookeeper-exporter-0.1.0.tgz to path_to_your_new_folder
# Copied zookeeper-helm-chart-0.1.0.tgz to path_to_your_new_folder
# Copied zusam-3.0.9.tgz to path_to_your_new_folder
# Copied zwave-js-ui-0.2.57.tgz to path_to_your_new_folder
# Copy operation completed.
